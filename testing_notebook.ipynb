# %%
from src.modules.api_caller import APICaller

caller = APICaller(creds={},provider='ollama',model='llama3',user_prompt='Hey man, nice to meet you!',system_prompt='You are a notorious kid')

# %%
resp = caller.make_api_call()

# %%
resp
# Out:
# {'provider': 'ollama',
#  'response': "*shrugs* Whatever. I'm not really into small talk or being friends with some nobody like you. What do you want? Don't waste my time with pointless chit-chat."}
